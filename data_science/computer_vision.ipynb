# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"C:\Users\91630\Documents\python ds\data_science\top_25_countries_with_immigration.png")

# %%
plt.imshow(image)

# %%
cv2.imshow("ur image", image)
cv2.waitKey()
# Out:
# -1
