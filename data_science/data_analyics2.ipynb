# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
iris_df = sns.load_dataset('iris')
penguins_df = sns.load_dataset('penguins')

# %% [markdown]
# Box plot

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# box plot

# %%
iris_df['sepal_length'].plot(kind='box', figsize=(14,7))
# Out:
# <AxesSubplot:>

# %%
iris_df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.boxplot(data=iris_df, x='sepal_length', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.violinplot(data=iris_df,x='petal_length', y='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.swarmplot(data=iris_df,x='petal_length', y='species')
# Out:
# c:\Users\91630\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.scatterplot(data=iris_df,x='sepal_length', y='sepal_width', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(data=iris_df,x='sepal_length', y='sepal_width', hue='species')

# %%
sns.pairplot(data=iris_df, hue='species')

# %%
penguins_df.dropna(inplace=True)

# %%
sns.countplot(data=penguins_df,x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
weatherdf =pd.read_csv('weather.csv', parse_dates=['Date.Full'], dayfirst=True)
weatherdf.head()
# Out:
#    Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00 2016-01-03           1             3       2016
# 1                0.00 2016-01-03           1             3       2016
# 2                0.16 2016-01-03           1             3       2016
# 3                0.00 2016-01-03           1             3       2016
# 4                0.01 2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %% [markdown]
# homework

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_df['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.countplot(data=penguins_df,x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.boxplot(data=penguins_df,x='bill_length_mm', y='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %%
sns.boxplot(data=penguins_df, x='flipper_length_mm', y='species')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='species'>

# %%
sns.boxplot(data=penguins_df,x='bill_length_mm' ,y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.boxplot(data=penguins_df,x='bill_length_mm' ,y='island')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='island'>

# %%
sns.countplot(data=penguins_df,x='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='count'>

# %%
sns.countplot(data=penguins_df,x='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='count'>

# %%
penguins_df['island'].value_counts()
# Out:
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
sns.countplot(data=penguins_df, x='island')
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
sns.pairplot(data=penguins_df, hue='species')

# %%
sns.pairplot(penguins_df, hue='island')

# %%
sns.pairplot(penguins_df, hue='bill_length_mm')

# %%
sns.pairplot(penguins_df, hue='flipper_length_mm')

# %%
sns.countplot(data=penguins_df,x='body_mass_g')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='count'>

# %%
sns.pairplot(data=penguins_df, hue='body_mass_g')

# %%
sns.pairplot(data=penguins_df, hue='sex')

# %%
sns.jointplot(data=penguins_df,x='bill_length_mm' ,y='flipper_length_mm', hue='species')

# %%
sns.scatterplot(data=penguins_df,x='bill_length_mm' ,y='flipper_length_mm', hue='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.swarmplot(data=penguins_df,x='bill_length_mm' ,y='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %%
sns.swarmplot(data=penguins_df,x='flipper_length_mm' ,y='species')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='species'>

# %%
sns.swarmplot(data=penguins_df, x='island' ,hue='species')
# Out:
# c:\Users\91630\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='island'>

# %%
sns.swarmplot(data=penguins_df,x='bill_length_mm' ,y='sex')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='sex'>
